# %%
import pandas as pd
import numpy as np
import re

# %%
dataPath = './rawData.csv'
df = pd.read_csv(dataPath)
df.head()
# Out:
#                                            name  danceability  energy  key  \
# 0         Peter Pan Was Right *by* Anson Seabra         0.661   0.517    5
# 1                Unloving You *by* Anson Seabra         0.765   0.393    6
# 2       Welcome to Wonderland *by* Anson Seabra         0.703   0.179    4
# 3  Keep Your Head Up Princess *by* Anson Seabra         0.689   0.143    6
# 4         Walked Through Hell *by* Anson Seabra         0.508   0.404   10
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -7.740     1       0.0406         0.223               0.0     0.116
# 1    -9.616     1       0.0311         0.633               0.0     0.142
# 2   -10.906     1       0.0366         0.949               0.0     0.102
# 3   -17.374     1       0.2640         0.970               0.0     0.109
# 4   -11.092     1       0.0788         0.664               0.0     0.104
#
#    valence    tempo            type                      id  \
# ...

# %%
print(df.count())
df.sample()
# Out:
# name                346
# danceability        346
# energy              346
# key                 346
# loudness            346
# mode                346
# speechiness         346
# acousticness        346
# instrumentalness    346
# liveness            346
# valence             346
# tempo               346
# type                346
# id                  346
# uri                 346
# track_href          346
# analysis_url        346
# duration_ms         346
# time_signature      346
# dtype: int64
#                         name  danceability  energy  key  loudness  mode  \
# 188  你不知道的事 *by* Leehom Wang         0.493   0.295    1    -9.924     1
#
#      speechiness  acousticness  instrumentalness  liveness  valence   tempo  \
# 188       0.0251         0.494               0.0      0.13    0.301  86.982
#
#                type                      id  \
# 188  audio_features  6KAw9NEvkVlIhg5T0G97M8
#
#                                       uri  \
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                                                   name  danceability  energy  \
# 0                Peter Pan Was Right *by* Anson Seabra         0.661   0.517
# 1                       Unloving You *by* Anson Seabra         0.765   0.393
# 2              Welcome to Wonderland *by* Anson Seabra         0.703   0.179
# 3         Keep Your Head Up Princess *by* Anson Seabra         0.689   0.143
# 4                Walked Through Hell *by* Anson Seabra         0.508   0.404
# ..                                                 ...           ...     ...
# 341                            Curious *by* Rich Brian         0.817   0.433
# 342  Tequila Sunrise (feat. AUGUST 08 & GoldLink) *...         0.800   0.545
# 343                           Best Lover *by* 88rising         0.740   0.663
# 344                         These Nights *by* 88rising         0.656   0.673
# 345                Diamonds + And Pearls *by* DPR LIVE         0.531   0.902
#
# ...

# %%
df
# Out:
#                                                   name  danceability  energy  \
# 0                Peter Pan Was Right *by* Anson Seabra         0.661   0.517
# 1                       Unloving You *by* Anson Seabra         0.765   0.393
# 2              Welcome to Wonderland *by* Anson Seabra         0.703   0.179
# 3         Keep Your Head Up Princess *by* Anson Seabra         0.689   0.143
# 4                Walked Through Hell *by* Anson Seabra         0.508   0.404
# ..                                                 ...           ...     ...
# 341                            Curious *by* Rich Brian         0.817   0.433
# 342  Tequila Sunrise (feat. AUGUST 08 & GoldLink) *...         0.800   0.545
# 343                           Best Lover *by* 88rising         0.740   0.663
# 344                         These Nights *by* 88rising         0.656   0.673
# 345                Diamonds + And Pearls *by* DPR LIVE         0.531   0.902
#
# ...

# %%
#kinda want the last name and first name to be separated
d = df['name'].str.split("*", 1, expand = True)
df[['song_name', 'artist_name']] = d
again_split = df['artist_name'].str.split(" ", 1, expand = True)
df[['fei', 'artist_name']] = again_split
df.drop(df.columns[[0, 21]], axis=1, inplace=True)
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.661   0.517    5    -7.740     1       0.0406      0.223000
# 1           0.765   0.393    6    -9.616     1       0.0311      0.633000
# 2           0.703   0.179    4   -10.906     1       0.0366      0.949000
# 3           0.689   0.143    6   -17.374     1       0.2640      0.970000
# 4           0.508   0.404   10   -11.092     1       0.0788      0.664000
# ..            ...     ...  ...       ...   ...          ...           ...
# 341         0.817   0.433    6    -7.260     1       0.0501      0.904000
# 342         0.800   0.545    0    -6.740     1       0.0765      0.031300
# 343         0.740   0.663    7    -5.393     1       0.2720      0.268000
# 344         0.656   0.673    6    -6.588     1       0.0477      0.000317
# 345         0.531   0.902    5    -2.886     1       0.1110      0.460000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
rrange = df.columns.tolist()

# %%
rrange
# Out:
# ['danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'song_name',
#  'artist_name']

# %%
rrange = rrange[-1:] + rrange[:-1]
rrange
# Out:
# ['artist_name',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature',
#  'song_name']

# %%
rrange = rrange[-1:] + rrange[:-1]
rrange
# Out:
# ['song_name',
#  'artist_name',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature']

# %%
df = df[rrange]
df
# Out:
#                                          song_name   artist_name  \
# 0                             Peter Pan Was Right   Anson Seabra
# 1                                    Unloving You   Anson Seabra
# 2                           Welcome to Wonderland   Anson Seabra
# 3                      Keep Your Head Up Princess   Anson Seabra
# 4                             Walked Through Hell   Anson Seabra
# ..                                             ...           ...
# 341                                       Curious     Rich Brian
# 342  Tequila Sunrise (feat. AUGUST 08 & GoldLink)       88rising
# 343                                    Best Lover       88rising
# 344                                  These Nights       88rising
# 345                         Diamonds + And Pearls       DPR LIVE
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.661   0.517    5    -7.740     1       0.0406      0.223000
# ...

# %%
df.to_csv('./cleansed_data.csv')
